# %% [markdown]
# GitHub

# %%
https://github.com/jcamilo22b/Lab_Biosenales.git

# %%
#ruta por comando en la terminal
#cd..     para devolverse de la ultima carpeta
#cd  + nombre carpeta     a que carpeta quiero entrar
#ls       para ver las carpetas 
#git clone + nombre carpeta (carpeta a clonar repositorio en el computador local)
#git add .   subir 
#git commit -m 'comentario'
#git push    (para subir la inf)
#git pull    (comando para bajar)
